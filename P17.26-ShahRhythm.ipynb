# %% [markdown]
# # Mathematical Model for Inventory Simulation
#
# ## **1. Inventory Components**
#
# The system's inventory consists of:
#
# - **On-Hand Inventory (I\_t)**: The stock available at time \(t\).
# - **On-Order Inventory (O\_t)**: The total quantity of outstanding orders in transit.
# - **Demand (D\_t)**: The quantity of goods requested by customers at time \(t\).
# - **Replenishment Orders (R\_t)**: The quantity of goods ordered at time \(t\) for future supply.
#
# ## **2. Order-Up-To Policy (S)**
#
# The policy follows an "order-up-to" model, meaning that the total inventory (on-hand + on-order) should not exceed the target level \(S\).
#
# - If \(I_t + O_t < S\), an order is placed to bring the inventory level up to \(S\).
# - The goal is to maintain an ideal system inventory of 1800 while ensuring a high fill rate.
#
# ## **3. Demand and Supply Dynamics**
#
# - The weekly demand follows a normal distribution:
#   $$
#   D_t \sim \mathcal{N}(\mu, \sigma)
#   $$
#   where mu = 200\) is the mean demand and sigma = 20/10 = 2 represents reduced uncertainty.
# - The on-hand inventory is updated as:
#   $$
#   I_{t+1} = I_t - D_t + \, \text{Incoming Shipment}
#   $$
# - Orders placed take up to 3 weeks to arrive, forming a pipeline of outstanding orders.
#
# ## **4. Performance Metrics**
#
# The evaluation is based on:
#
# 1. **Fill Rate:** The proportion of demand met from available stock, given by:
#    $$
#    \text{Fill Rate} = \frac{\text{Total Demand Fulfilled}}{\text{Total Demand}}
#    $$
# 2. **Deviation from Ideal Inventory (1800):**
#    - The average inventory level should be as close as possible to 1800.
#    - The absolute deviation is minimized:
#      $$
#      \min |I_{avg} - 1800|
#      $$
#
# ## **5. Decision Criteria**
#
# The best inventory policy is chosen based on:
#
# - Maintaining a high fill rate (\(\geq 95\%\)).
# - Keeping the average inventory level as close to 1800 as possible.
# - The order-up-to values that achieve these goals are recommended for implementation.

# %% [markdown]
# # Python Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameters and Policy Definition

# %%
np.random.seed(42)
demand_mean = 200  # Average weekly demand
demand_std = 20 / 10  # Reduced uncertainty (std dev reduced by factor of 10)
weeks = 52  # Simulation period


# Inventory policies to evaluate
policies = [
    (200, 400, 300, 1800), (200, 400, 300, 1804), (200, 400, 300, 1805), 
    (200, 400, 300, 1807), (200, 402, 301, 1800), (200, 402, 301, 1801), 
    (201, 402, 301, 1801), (201, 402, 301, 1803)
]

# %% [markdown]
# # Defining Functions and Using For Loops for Simulating Inventory Performamnce

# %%
def simulate_inventory(policy, weeks=52):
    """
    Simulates inventory performance based on given policy and weeks.
    
    Args:
    policy (tuple): A tuple containing (transit_1, transit_2, transit_3, order_up_to).
    weeks (int): Number of weeks to simulate.
    
    Returns:
    tuple: Average inventory level, average fill rate, and inventory level over time.
    """
    transit_1, transit_2, transit_3, order_up_to = policy
    inventory_levels = []
    fill_rates = []
    on_hand = order_up_to - (transit_1 + transit_2 + transit_3)  # Initial on-hand inventory
    on_order = [transit_1, transit_2, transit_3]  # Pipeline orders
    
    print(f"\nSimulating policy: {policy}")
    for week in range(weeks):
        demand = max(0, int(np.random.normal(demand_mean, demand_std)))
        print(f"Week {week + 1}: Demand = {demand}, On-hand before demand = {on_hand}")
        
        # Check if demand can be fulfilled
        if on_hand >= demand:
            on_hand -= demand
            fill_rates.append(1)
        else:
            fill_rates.append(on_hand / demand if demand > 0 else 1)
            on_hand = 0  # Demand exceeds supply
        
        # Receive next shipment
        received_shipment = on_order.pop(0)
        on_hand += received_shipment
        print(f"Week {week + 1}: Received shipment = {received_shipment}, On-hand after = {on_hand}")
        
        # Place new order if needed
        if on_hand + sum(on_order) < order_up_to:
            new_order = order_up_to - (on_hand + sum(on_order))
            on_order.append(new_order)
            print(f"Week {week + 1}: Placing new order = {new_order}")
        else:
            on_order.append(0)
        
        inventory_levels.append(on_hand + sum(on_order))
    
    avg_inventory = np.mean(inventory_levels)
    avg_fill_rate = np.mean(fill_rates)
    return avg_inventory, avg_fill_rate, inventory_levels

# Run simulations and evaluate policies
results = []
policy_inventory_levels = {}
for policy in policies:
    avg_inventory, avg_fill_rate, inventory_levels = simulate_inventory(policy, weeks)
    results.append((policy, avg_inventory, avg_fill_rate))
    policy_inventory_levels[policy] = inventory_levels
# Out:
# Simulating policy: (200, 400, 300, 1800)
# Week 1: Demand = 197, On-hand before demand = 900
# Week 1: Received shipment = 200, On-hand after = 903
# Week 1: Placing new order = 197
# Week 2: Demand = 198, On-hand before demand = 903
# Week 2: Received shipment = 400, On-hand after = 1105
# Week 2: Placing new order = 198
# Week 3: Demand = 199, On-hand before demand = 1105
# Week 3: Received shipment = 300, On-hand after = 1206
# Week 3: Placing new order = 199
# Week 4: Demand = 200, On-hand before demand = 1206
# Week 4: Received shipment = 197, On-hand after = 1203
# Week 4: Placing new order = 200
# Week 5: Demand = 203, On-hand before demand = 1203
# Week 5: Received shipment = 198, On-hand after = 1198
# Week 5: Placing new order = 203
# Week 6: Demand = 198, On-hand before demand = 1198
# Week 6: Received shipment = 199, On-hand after = 1199
# Week 6: Placing new order = 198
# Week 7: Demand = 201, On-hand before demand = 1199
# Week 7: Received shipment = 200, On-hand after = 1198
# Week 7: Placing new order = 201
# Week 8: Demand = 199, On-hand before demand = 1198
# Week 8: Received shipment = 203, On-hand after = 1202
# Week 8: Placing new order = 199
# Week 9: Demand = 199, On-hand before demand = 1202
# Week 9: Received shipment = 198, On-hand after = 1201
# Week 9: Placing new order = 199
# Week 10: Demand = 201, On-hand before demand = 1201
# Week 10: Received shipment = 201, On-hand after = 1201
# Week 10: Placing new order = 201
# Week 11: Demand = 197, On-hand before demand = 1201
# Week 11: Received shipment = 199, On-hand after = 1203
# Week 11: Placing new order = 197
# Week 12: Demand = 200, On-hand before demand = 1203
# Week 12: Received shipment = 199, On-hand after = 1202
# Week 12: Placing new order = 200
# Week 13: Demand = 200, On-hand before demand = 1202
# Week 13: Received shipment = 201, On-hand after = 1203
# Week 13: Placing new order = 200
# Week 14: Demand = 200, On-hand before demand = 1203
# Week 14: Received shipment = 197, On-hand after = 1200
# Week 14: Placing new order = 200
# Week 15: Demand = 200, On-hand before demand = 1200
# Week 15: Received shipment = 200, On-hand after = 1200
# Week 15: Placing new order = 200
# Week 16: Demand = 204, On-hand before demand = 1200
# Week 16: Received shipment = 200, On-hand after = 1196
# Week 16: Placing new order = 204
# Week 17: Demand = 198, On-hand before demand = 1196
# Week 17: Received shipment = 200, On-hand after = 1198
# Week 17: Placing new order = 198
# Week 18: Demand = 198, On-hand before demand = 1198
# Week 18: Received shipment = 200, On-hand after = 1200
# Week 18: Placing new order = 198
# Week 19: Demand = 198, On-hand before demand = 1200
# Week 19: Received shipment = 204, On-hand after = 1206
# Week 19: Placing new order = 198
# Week 20: Demand = 198, On-hand before demand = 1206
# Week 20: Received shipment = 198, On-hand after = 1206
# Week 20: Placing new order = 198
# Week 21: Demand = 198, On-hand before demand = 1206
# Week 21: Received shipment = 198, On-hand after = 1206
# Week 21: Placing new order = 198
# Week 22: Demand = 202, On-hand before demand = 1206
# Week 22: Received shipment = 198, On-hand after = 1202
# Week 22: Placing new order = 202
# Week 23: Demand = 202, On-hand before demand = 1202
# Week 23: Received shipment = 198, On-hand after = 1198
# Week 23: Placing new order = 202
# Week 24: Demand = 198, On-hand before demand = 1198
# Week 24: Received shipment = 198, On-hand after = 1198
# Week 24: Placing new order = 198
# Week 25: Demand = 198, On-hand before demand = 1198
# Week 25: Received shipment = 202, On-hand after = 1202
# Week 25: Placing new order = 198
# Week 26: Demand = 200, On-hand before demand = 1202
# Week 26: Received shipment = 202, On-hand after = 1204
# Week 26: Placing new order = 200
# Week 27: Demand = 198, On-hand before demand = 1204
# Week 27: Received shipment = 198, On-hand after = 1204
# Week 27: Placing new order = 198
# Week 28: Demand = 201, On-hand before demand = 1204
# Week 28: Received shipment = 198, On-hand after = 1201
# Week 28: Placing new order = 201
# Week 29: Demand = 200, On-hand before demand = 1201
# Week 29: Received shipment = 200, On-hand after = 1201
# Week 29: Placing new order = 200
# Week 30: Demand = 196, On-hand before demand = 1201
# Week 30: Received shipment = 198, On-hand after = 1203
# Week 30: Placing new order = 196
# Week 31: Demand = 203, On-hand before demand = 1203
# Week 31: Received shipment = 201, On-hand after = 1201
# Week 31: Placing new order = 203
# Week 32: Demand = 203, On-hand before demand = 1201
# Week 32: Received shipment = 200, On-hand after = 1198
# Week 32: Placing new order = 203
# Week 33: Demand = 198, On-hand before demand = 1198
# Week 33: Received shipment = 196, On-hand after = 1196
# Week 33: Placing new order = 198
# Week 34: Demand = 199, On-hand before demand = 1196
# Week 34: Received shipment = 203, On-hand after = 1200
# Week 34: Placing new order = 199
# Week 35: Demand = 200, On-hand before demand = 1200
# Week 35: Received shipment = 203, On-hand after = 1203
# Week 35: Placing new order = 200
# Week 36: Demand = 200, On-hand before demand = 1203
# Week 36: Received shipment = 198, On-hand after = 1201
# Week 36: Placing new order = 200
# Week 37: Demand = 201, On-hand before demand = 1201
# Week 37: Received shipment = 199, On-hand after = 1199
# Week 37: Placing new order = 201
# Week 38: Demand = 204, On-hand before demand = 1199
# Week 38: Received shipment = 200, On-hand after = 1195
# Week 38: Placing new order = 204
# Week 39: Demand = 199, On-hand before demand = 1195
# Week 39: Received shipment = 200, On-hand after = 1196
# Week 39: Placing new order = 199
# Week 40: Demand = 198, On-hand before demand = 1196
# Week 40: Received shipment = 201, On-hand after = 1199
# Week 40: Placing new order = 198
# Week 41: Demand = 197, On-hand before demand = 1199
# Week 41: Received shipment = 204, On-hand after = 1206
# Week 41: Placing new order = 197
# Week 42: Demand = 198, On-hand before demand = 1206
# Week 42: Received shipment = 199, On-hand after = 1207
# Week 42: Placing new order = 198
# Week 43: Demand = 199, On-hand before demand = 1207
# Week 43: Received shipment = 198, On-hand after = 1206
# Week 43: Placing new order = 199
# Week 44: Demand = 203, On-hand before demand = 1206
# Week 44: Received shipment = 197, On-hand after = 1200
# Week 44: Placing new order = 203
# Week 45: Demand = 198, On-hand before demand = 1200
# Week 45: Received shipment = 198, On-hand after = 1200
# Week 45: Placing new order = 198
# Week 46: Demand = 200, On-hand before demand = 1200
# Week 46: Received shipment = 199, On-hand after = 1199
# Week 46: Placing new order = 200
# Week 47: Demand = 199, On-hand before demand = 1199
# Week 47: Received shipment = 203, On-hand after = 1203
# Week 47: Placing new order = 199
# Week 48: Demand = 202, On-hand before demand = 1203
# Week 48: Received shipment = 198, On-hand after = 1199
# Week 48: Placing new order = 202
# Week 49: Demand = 205, On-hand before demand = 1199
# Week 49: Received shipment = 200, On-hand after = 1194
# Week 49: Placing new order = 205
# Week 50: Demand = 198, On-hand before demand = 1194
# Week 50: Received shipment = 199, On-hand after = 1195
# Week 50: Placing new order = 198
# Week 51: Demand = 199, On-hand before demand = 1195
# Week 51: Received shipment = 202, On-hand after = 1198
# Week 51: Placing new order = 199
# Week 52: Demand = 202, On-hand before demand = 1198
# Week 52: Received shipment = 205, On-hand after = 1201
# Week 52: Placing new order = 202
#
# Simulating policy: (200, 400, 300, 1804)
# Week 1: Demand = 201, On-hand before demand = 904
# Week 1: Received shipment = 200, On-hand after = 903
# Week 1: Placing new order = 201
# Week 2: Demand = 203, On-hand before demand = 903
# Week 2: Received shipment = 400, On-hand after = 1100
# Week 2: Placing new order = 203
# Week 3: Demand = 201, On-hand before demand = 1100
# Week 3: Received shipment = 300, On-hand after = 1199
# Week 3: Placing new order = 201
# Week 4: Demand = 199, On-hand before demand = 1199
# Week 4: Received shipment = 201, On-hand after = 1201
# Week 4: Placing new order = 199
# Week 5: Demand = 201, On-hand before demand = 1201
# Week 5: Received shipment = 203, On-hand after = 1203
# Week 5: Placing new order = 201
# Week 6: Demand = 202, On-hand before demand = 1203
# Week 6: Received shipment = 201, On-hand after = 1202
# Week 6: Placing new order = 202
# Week 7: Demand = 201, On-hand before demand = 1202
# Week 7: Received shipment = 199, On-hand after = 1200
# Week 7: Placing new order = 201
# Week 8: Demand = 201, On-hand before demand = 1200
# Week 8: Received shipment = 201, On-hand after = 1200
# Week 8: Placing new order = 201
# Week 9: Demand = 202, On-hand before demand = 1200
# Week 9: Received shipment = 202, On-hand after = 1200
# Week 9: Placing new order = 202
# Week 10: Demand = 202, On-hand before demand = 1200
# Week 10: Received shipment = 201, On-hand after = 1199
# Week 10: Placing new order = 202
# Week 11: Demand = 202, On-hand before demand = 1199
# Week 11: Received shipment = 201, On-hand after = 1198
# Week 11: Placing new order = 202
# Week 12: Demand = 201, On-hand before demand = 1198
# Week 12: Received shipment = 202, On-hand after = 1199
# Week 12: Placing new order = 201
# Week 13: Demand = 199, On-hand before demand = 1199
# Week 13: Received shipment = 202, On-hand after = 1202
# Week 13: Placing new order = 199
# Week 14: Demand = 200, On-hand before demand = 1202
# Week 14: Received shipment = 202, On-hand after = 1204
# Week 14: Placing new order = 200
# Week 15: Demand = 202, On-hand before demand = 1204
# Week 15: Received shipment = 201, On-hand after = 1203
# Week 15: Placing new order = 202
# Week 16: Demand = 198, On-hand before demand = 1203
# Week 16: Received shipment = 199, On-hand after = 1204
# Week 16: Placing new order = 198
# Week 17: Demand = 200, On-hand before demand = 1204
# Week 17: Received shipment = 200, On-hand after = 1204
# Week 17: Placing new order = 200
# Week 18: Demand = 199, On-hand before demand = 1204
# Week 18: Received shipment = 202, On-hand after = 1207
# Week 18: Placing new order = 199
# Week 19: Demand = 200, On-hand before demand = 1207
# Week 19: Received shipment = 198, On-hand after = 1205
# Week 19: Placing new order = 200
# Week 20: Demand = 202, On-hand before demand = 1205
# Week 20: Received shipment = 200, On-hand after = 1203
# Week 20: Placing new order = 202
# Week 21: Demand = 200, On-hand before demand = 1203
# Week 21: Received shipment = 199, On-hand after = 1202
# Week 21: Placing new order = 200
# Week 22: Demand = 200, On-hand before demand = 1202
# Week 22: Received shipment = 200, On-hand after = 1202
# Week 22: Placing new order = 200
# Week 23: Demand = 197, On-hand before demand = 1202
# Week 23: Received shipment = 202, On-hand after = 1207
# Week 23: Placing new order = 197
# Week 24: Demand = 201, On-hand before demand = 1207
# Week 24: Received shipment = 200, On-hand after = 1206
# Week 24: Placing new order = 201
# Week 25: Demand = 201, On-hand before demand = 1206
# Week 25: Received shipment = 200, On-hand after = 1205
# Week 25: Placing new order = 201
# Week 26: Demand = 204, On-hand before demand = 1205
# Week 26: Received shipment = 197, On-hand after = 1198
# Week 26: Placing new order = 204
# Week 27: Demand = 199, On-hand before demand = 1198
# Week 27: Received shipment = 201, On-hand after = 1200
# Week 27: Placing new order = 199
# Week 28: Demand = 200, On-hand before demand = 1200
# Week 28: Received shipment = 201, On-hand after = 1201
# Week 28: Placing new order = 200
# Week 29: Demand = 200, On-hand before demand = 1201
# Week 29: Received shipment = 204, On-hand after = 1205
# Week 29: Placing new order = 200
# Week 30: Demand = 203, On-hand before demand = 1205
# Week 30: Received shipment = 199, On-hand after = 1201
# Week 30: Placing new order = 203
# Week 31: Demand = 199, On-hand before demand = 1201
# Week 31: Received shipment = 200, On-hand after = 1202
# Week 31: Placing new order = 199
# Week 32: Demand = 200, On-hand before demand = 1202
# Week 32: Received shipment = 200, On-hand after = 1202
# Week 32: Placing new order = 200
# Week 33: Demand = 201, On-hand before demand = 1202
# Week 33: Received shipment = 203, On-hand after = 1204
# Week 33: Placing new order = 201
# Week 34: Demand = 200, On-hand before demand = 1204
# Week 34: Received shipment = 199, On-hand after = 1203
# Week 34: Placing new order = 200
# Week 35: Demand = 199, On-hand before demand = 1203
# Week 35: Received shipment = 200, On-hand after = 1204
# Week 35: Placing new order = 199
# Week 36: Demand = 200, On-hand before demand = 1204
# Week 36: Received shipment = 201, On-hand after = 1205
# Week 36: Placing new order = 200
# Week 37: Demand = 202, On-hand before demand = 1205
# Week 37: Received shipment = 200, On-hand after = 1203
# Week 37: Placing new order = 202
# Week 38: Demand = 197, On-hand before demand = 1203
# Week 38: Received shipment = 199, On-hand after = 1205
# Week 38: Placing new order = 197
# Week 39: Demand = 200, On-hand before demand = 1205
# Week 39: Received shipment = 200, On-hand after = 1205
# Week 39: Placing new order = 200
# Week 40: Demand = 198, On-hand before demand = 1205
# Week 40: Received shipment = 202, On-hand after = 1209
# Week 40: Placing new order = 198
# Week 41: Demand = 202, On-hand before demand = 1209
# Week 41: Received shipment = 197, On-hand after = 1204
# Week 41: Placing new order = 202
# Week 42: Demand = 196, On-hand before demand = 1204
# Week 42: Received shipment = 200, On-hand after = 1208
# Week 42: Placing new order = 196
# Week 43: Demand = 198, On-hand before demand = 1208
# Week 43: Received shipment = 198, On-hand after = 1208
# Week 43: Placing new order = 198
# Week 44: Demand = 200, On-hand before demand = 1208
# Week 44: Received shipment = 202, On-hand after = 1210
# Week 44: Placing new order = 200
# Week 45: Demand = 203, On-hand before demand = 1210
# Week 45: Received shipment = 196, On-hand after = 1203
# Week 45: Placing new order = 203
# Week 46: Demand = 199, On-hand before demand = 1203
# Week 46: Received shipment = 198, On-hand after = 1202
# Week 46: Placing new order = 199
# Week 47: Demand = 198, On-hand before demand = 1202
# Week 47: Received shipment = 200, On-hand after = 1204
# Week 47: Placing new order = 198
# Week 48: Demand = 203, On-hand before demand = 1204
# Week 48: Received shipment = 203, On-hand after = 1204
# Week 48: Placing new order = 203
# Week 49: Demand = 197, On-hand before demand = 1204
# Week 49: Received shipment = 199, On-hand after = 1206
# Week 49: Placing new order = 197
# Week 50: Demand = 195, On-hand before demand = 1206
# Week 50: Received shipment = 198, On-hand after = 1209
# Week 50: Placing new order = 195
# Week 51: Demand = 200, On-hand before demand = 1209
# Week 51: Received shipment = 203, On-hand after = 1212
# Week 51: Placing new order = 200
# Week 52: Demand = 198, On-hand before demand = 1212
# Week 52: Received shipment = 197, On-hand after = 1211
# Week 52: Placing new order = 198
#
# Simulating policy: (200, 400, 300, 1805)
# Week 1: Demand = 197, On-hand before demand = 905
# Week 1: Received shipment = 200, On-hand after = 908
# Week 1: Placing new order = 197
# Week 2: Demand = 201, On-hand before demand = 908
# Week 2: Received shipment = 400, On-hand after = 1107
# Week 2: Placing new order = 201
# Week 3: Demand = 200, On-hand before demand = 1107
# Week 3: Received shipment = 300, On-hand after = 1207
# Week 3: Placing new order = 200
# Week 4: Demand = 198, On-hand before demand = 1207
# Week 4: Received shipment = 197, On-hand after = 1206
# Week 4: Placing new order = 198
# Week 5: Demand = 197, On-hand before demand = 1206
# Week 5: Received shipment = 201, On-hand after = 1210
# Week 5: Placing new order = 197
# Week 6: Demand = 201, On-hand before demand = 1210
# Week 6: Received shipment = 200, On-hand after = 1209
# Week 6: Placing new order = 201
# Week 7: Demand = 201, On-hand before demand = 1209
# Week 7: Received shipment = 198, On-hand after = 1206
# Week 7: Placing new order = 201
# Week 8: Demand = 199, On-hand before demand = 1206
# Week 8: Received shipment = 197, On-hand after = 1204
# Week 8: Placing new order = 199
# Week 9: Demand = 203, On-hand before demand = 1204
# Week 9: Received shipment = 201, On-hand after = 1202
# Week 9: Placing new order = 203
# Week 10: Demand = 197, On-hand before demand = 1202
# Week 10: Received shipment = 201, On-hand after = 1206
# Week 10: Placing new order = 197
# Week 11: Demand = 196, On-hand before demand = 1206
# Week 11: Received shipment = 199, On-hand after = 1209
# Week 11: Placing new order = 196
# Week 12: Demand = 198, On-hand before demand = 1209
# Week 12: Received shipment = 203, On-hand after = 1214
# Week 12: Placing new order = 198
# Week 13: Demand = 199, On-hand before demand = 1214
# Week 13: Received shipment = 197, On-hand after = 1212
# Week 13: Placing new order = 199
# Week 14: Demand = 200, On-hand before demand = 1212
# Week 14: Received shipment = 196, On-hand after = 1208
# Week 14: Placing new order = 200
# Week 15: Demand = 199, On-hand before demand = 1208
# Week 15: Received shipment = 198, On-hand after = 1207
# Week 15: Placing new order = 199
# Week 16: Demand = 200, On-hand before demand = 1207
# Week 16: Received shipment = 199, On-hand after = 1206
# Week 16: Placing new order = 200
# Week 17: Demand = 197, On-hand before demand = 1206
# Week 17: Received shipment = 200, On-hand after = 1209
# Week 17: Placing new order = 197
# Week 18: Demand = 202, On-hand before demand = 1209
# Week 18: Received shipment = 199, On-hand after = 1206
# Week 18: Placing new order = 202
# Week 19: Demand = 199, On-hand before demand = 1206
# Week 19: Received shipment = 200, On-hand after = 1207
# Week 19: Placing new order = 199
# Week 20: Demand = 202, On-hand before demand = 1207
# Week 20: Received shipment = 197, On-hand after = 1202
# Week 20: Placing new order = 202
# Week 21: Demand = 200, On-hand before demand = 1202
# Week 21: Received shipment = 202, On-hand after = 1204
# Week 21: Placing new order = 200
# Week 22: Demand = 200, On-hand before demand = 1204
# Week 22: Received shipment = 199, On-hand after = 1203
# Week 22: Placing new order = 200
# Week 23: Demand = 201, On-hand before demand = 1203
# Week 23: Received shipment = 202, On-hand after = 1204
# Week 23: Placing new order = 201
# Week 24: Demand = 200, On-hand before demand = 1204
# Week 24: Received shipment = 200, On-hand after = 1204
# Week 24: Placing new order = 200
# Week 25: Demand = 201, On-hand before demand = 1204
# Week 25: Received shipment = 200, On-hand after = 1203
# Week 25: Placing new order = 201
# Week 26: Demand = 202, On-hand before demand = 1203
# Week 26: Received shipment = 201, On-hand after = 1202
# Week 26: Placing new order = 202
# Week 27: Demand = 200, On-hand before demand = 1202
# Week 27: Received shipment = 200, On-hand after = 1202
# Week 27: Placing new order = 200
# Week 28: Demand = 201, On-hand before demand = 1202
# Week 28: Received shipment = 201, On-hand after = 1202
# Week 28: Placing new order = 201
# Week 29: Demand = 199, On-hand before demand = 1202
# Week 29: Received shipment = 202, On-hand after = 1205
# Week 29: Placing new order = 199
# Week 30: Demand = 202, On-hand before demand = 1205
# Week 30: Received shipment = 200, On-hand after = 1203
# Week 30: Placing new order = 202
# Week 31: Demand = 198, On-hand before demand = 1203
# Week 31: Received shipment = 201, On-hand after = 1206
# Week 31: Placing new order = 198
# Week 32: Demand = 203, On-hand before demand = 1206
# Week 32: Received shipment = 199, On-hand after = 1202
# Week 32: Placing new order = 203
# Week 33: Demand = 199, On-hand before demand = 1202
# Week 33: Received shipment = 202, On-hand after = 1205
# Week 33: Placing new order = 199
# Week 34: Demand = 197, On-hand before demand = 1205
# Week 34: Received shipment = 198, On-hand after = 1206
# Week 34: Placing new order = 197
# Week 35: Demand = 200, On-hand before demand = 1206
# Week 35: Received shipment = 203, On-hand after = 1209
# Week 35: Placing new order = 200
# Week 36: Demand = 198, On-hand before demand = 1209
# Week 36: Received shipment = 199, On-hand after = 1210
# Week 36: Placing new order = 198
# Week 37: Demand = 201, On-hand before demand = 1210
# Week 37: Received shipment = 197, On-hand after = 1206
# Week 37: Placing new order = 201
# Week 38: Demand = 198, On-hand before demand = 1206
# Week 38: Received shipment = 200, On-hand after = 1208
# Week 38: Placing new order = 198
# Week 39: Demand = 199, On-hand before demand = 1208
# Week 39: Received shipment = 198, On-hand after = 1207
# Week 39: Placing new order = 199
# Week 40: Demand = 196, On-hand before demand = 1207
# Week 40: Received shipment = 201, On-hand after = 1212
# Week 40: Placing new order = 196
# Week 41: Demand = 199, On-hand before demand = 1212
# Week 41: Received shipment = 198, On-hand after = 1211
# Week 41: Placing new order = 199
# Week 42: Demand = 195, On-hand before demand = 1211
# Week 42: Received shipment = 199, On-hand after = 1215
# Week 42: Placing new order = 195
# Week 43: Demand = 196, On-hand before demand = 1215
# Week 43: Received shipment = 196, On-hand after = 1215
# Week 43: Placing new order = 196
# Week 44: Demand = 201, On-hand before demand = 1215
# Week 44: Received shipment = 199, On-hand after = 1213
# Week 44: Placing new order = 201
# Week 45: Demand = 201, On-hand before demand = 1213
# Week 45: Received shipment = 195, On-hand after = 1207
# Week 45: Placing new order = 201
# Week 46: Demand = 200, On-hand before demand = 1207
# Week 46: Received shipment = 196, On-hand after = 1203
# Week 46: Placing new order = 200
# Week 47: Demand = 198, On-hand before demand = 1203
# Week 47: Received shipment = 201, On-hand after = 1206
# Week 47: Placing new order = 198
# Week 48: Demand = 199, On-hand before demand = 1206
# Week 48: Received shipment = 201, On-hand after = 1208
# Week 48: Placing new order = 199
# Week 49: Demand = 199, On-hand before demand = 1208
# Week 49: Received shipment = 200, On-hand after = 1209
# Week 49: Placing new order = 199
# Week 50: Demand = 197, On-hand before demand = 1209
# Week 50: Received shipment = 198, On-hand after = 1210
# Week 50: Placing new order = 197
# Week 51: Demand = 203, On-hand before demand = 1210
# Week 51: Received shipment = 199, On-hand after = 1206
# Week 51: Placing new order = 203
# Week 52: Demand = 201, On-hand before demand = 1206
# Week 52: Received shipment = 199, On-hand after = 1204
# Week 52: Placing new order = 201
#
# Simulating policy: (200, 400, 300, 1807)
# Week 1: Demand = 199, On-hand before demand = 907
# Week 1: Received shipment = 200, On-hand after = 908
# Week 1: Placing new order = 199
# Week 2: Demand = 200, On-hand before demand = 908
# Week 2: Received shipment = 400, On-hand after = 1108
# Week 2: Placing new order = 200
# Week 3: Demand = 200, On-hand before demand = 1108
# Week 3: Received shipment = 300, On-hand after = 1208
# Week 3: Placing new order = 200
# Week 4: Demand = 195, On-hand before demand = 1208
# Week 4: Received shipment = 199, On-hand after = 1212
# Week 4: Placing new order = 195
# Week 5: Demand = 199, On-hand before demand = 1212
# Week 5: Received shipment = 200, On-hand after = 1213
# Week 5: Placing new order = 199
# Week 6: Demand = 198, On-hand before demand = 1213
# Week 6: Received shipment = 200, On-hand after = 1215
# Week 6: Placing new order = 198
# Week 7: Demand = 197, On-hand before demand = 1215
# Week 7: Received shipment = 195, On-hand after = 1213
# Week 7: Placing new order = 197
# Week 8: Demand = 199, On-hand before demand = 1213
# Week 8: Received shipment = 199, On-hand after = 1213
# Week 8: Placing new order = 199
# Week 9: Demand = 203, On-hand before demand = 1213
# Week 9: Received shipment = 198, On-hand after = 1208
# Week 9: Placing new order = 203
# Week 10: Demand = 201, On-hand before demand = 1208
# Week 10: Received shipment = 197, On-hand after = 1204
# Week 10: Placing new order = 201
# Week 11: Demand = 198, On-hand before demand = 1204
# Week 11: Received shipment = 199, On-hand after = 1205
# Week 11: Placing new order = 198
# Week 12: Demand = 201, On-hand before demand = 1205
# Week 12: Received shipment = 203, On-hand after = 1207
# Week 12: Placing new order = 201
# Week 13: Demand = 202, On-hand before demand = 1207
# Week 13: Received shipment = 201, On-hand after = 1206
# Week 13: Placing new order = 202
# Week 14: Demand = 201, On-hand before demand = 1206
# Week 14: Received shipment = 198, On-hand after = 1203
# Week 14: Placing new order = 201
# Week 15: Demand = 200, On-hand before demand = 1203
# Week 15: Received shipment = 201, On-hand after = 1204
# Week 15: Placing new order = 200
# Week 16: Demand = 198, On-hand before demand = 1204
# Week 16: Received shipment = 202, On-hand after = 1208
# Week 16: Placing new order = 198
# Week 17: Demand = 201, On-hand before demand = 1208
# Week 17: Received shipment = 201, On-hand after = 1208
# Week 17: Placing new order = 201
# Week 18: Demand = 200, On-hand before demand = 1208
# Week 18: Received shipment = 200, On-hand after = 1208
# Week 18: Placing new order = 200
# Week 19: Demand = 201, On-hand before demand = 1208
# Week 19: Received shipment = 198, On-hand after = 1205
# Week 19: Placing new order = 201
# Week 20: Demand = 201, On-hand before demand = 1205
# Week 20: Received shipment = 201, On-hand after = 1205
# Week 20: Placing new order = 201
# Week 21: Demand = 202, On-hand before demand = 1205
# Week 21: Received shipment = 200, On-hand after = 1203
# Week 21: Placing new order = 202
# Week 22: Demand = 198, On-hand before demand = 1203
# Week 22: Received shipment = 201, On-hand after = 1206
# Week 22: Placing new order = 198
# Week 23: Demand = 202, On-hand before demand = 1206
# Week 23: Received shipment = 201, On-hand after = 1205
# Week 23: Placing new order = 202
# Week 24: Demand = 200, On-hand before demand = 1205
# Week 24: Received shipment = 202, On-hand after = 1207
# Week 24: Placing new order = 200
# Week 25: Demand = 204, On-hand before demand = 1207
# Week 25: Received shipment = 198, On-hand after = 1201
# Week 25: Placing new order = 204
# Week 26: Demand = 198, On-hand before demand = 1201
# Week 26: Received shipment = 202, On-hand after = 1205
# Week 26: Placing new order = 198
# Week 27: Demand = 203, On-hand before demand = 1205
# Week 27: Received shipment = 200, On-hand after = 1202
# Week 27: Placing new order = 203
# Week 28: Demand = 200, On-hand before demand = 1202
# Week 28: Received shipment = 204, On-hand after = 1206
# Week 28: Placing new order = 200
# Week 29: Demand = 198, On-hand before demand = 1206
# Week 29: Received shipment = 198, On-hand after = 1206
# Week 29: Placing new order = 198
# Week 30: Demand = 199, On-hand before demand = 1206
# Week 30: Received shipment = 203, On-hand after = 1210
# Week 30: Placing new order = 199
# Week 31: Demand = 199, On-hand before demand = 1210
# Week 31: Received shipment = 200, On-hand after = 1211
# Week 31: Placing new order = 199
# Week 32: Demand = 200, On-hand before demand = 1211
# Week 32: Received shipment = 198, On-hand after = 1209
# Week 32: Placing new order = 200
# Week 33: Demand = 201, On-hand before demand = 1209
# Week 33: Received shipment = 199, On-hand after = 1207
# Week 33: Placing new order = 201
# Week 34: Demand = 198, On-hand before demand = 1207
# Week 34: Received shipment = 199, On-hand after = 1208
# Week 34: Placing new order = 198
# Week 35: Demand = 199, On-hand before demand = 1208
# Week 35: Received shipment = 200, On-hand after = 1209
# Week 35: Placing new order = 199
# Week 36: Demand = 204, On-hand before demand = 1209
# Week 36: Received shipment = 201, On-hand after = 1206
# Week 36: Placing new order = 204
# Week 37: Demand = 203, On-hand before demand = 1206
# Week 37: Received shipment = 198, On-hand after = 1201
# Week 37: Placing new order = 203
# Week 38: Demand = 200, On-hand before demand = 1201
# Week 38: Received shipment = 199, On-hand after = 1200
# Week 38: Placing new order = 200
# Week 39: Demand = 200, On-hand before demand = 1200
# Week 39: Received shipment = 204, On-hand after = 1204
# Week 39: Placing new order = 200
# Week 40: Demand = 200, On-hand before demand = 1204
# Week 40: Received shipment = 203, On-hand after = 1207
# Week 40: Placing new order = 200
# Week 41: Demand = 201, On-hand before demand = 1207
# Week 41: Received shipment = 200, On-hand after = 1206
# Week 41: Placing new order = 201
# Week 42: Demand = 197, On-hand before demand = 1206
# Week 42: Received shipment = 200, On-hand after = 1209
# Week 42: Placing new order = 197
# Week 43: Demand = 199, On-hand before demand = 1209
# Week 43: Received shipment = 200, On-hand after = 1210
# Week 43: Placing new order = 199
# Week 44: Demand = 196, On-hand before demand = 1210
# Week 44: Received shipment = 201, On-hand after = 1215
# Week 44: Placing new order = 196
# Week 45: Demand = 200, On-hand before demand = 1215
# Week 45: Received shipment = 197, On-hand after = 1212
# Week 45: Placing new order = 200
# Week 46: Demand = 201, On-hand before demand = 1212
# Week 46: Received shipment = 199, On-hand after = 1210
# Week 46: Placing new order = 201
# Week 47: Demand = 199, On-hand before demand = 1210
# Week 47: Received shipment = 196, On-hand after = 1207
# Week 47: Placing new order = 199
# Week 48: Demand = 203, On-hand before demand = 1207
# Week 48: Received shipment = 200, On-hand after = 1204
# Week 48: Placing new order = 203
# Week 49: Demand = 197, On-hand before demand = 1204
# Week 49: Received shipment = 201, On-hand after = 1208
# Week 49: Placing new order = 197
# Week 50: Demand = 197, On-hand before demand = 1208
# Week 50: Received shipment = 199, On-hand after = 1210
# Week 50: Placing new order = 197
# Week 51: Demand = 200, On-hand before demand = 1210
# Week 51: Received shipment = 203, On-hand after = 1213
# Week 51: Placing new order = 200
# Week 52: Demand = 202, On-hand before demand = 1213
# Week 52: Received shipment = 197, On-hand after = 1208
# Week 52: Placing new order = 202
#
# Simulating policy: (200, 402, 301, 1800)
# Week 1: Demand = 203, On-hand before demand = 897
# Week 1: Received shipment = 200, On-hand after = 894
# Week 1: Placing new order = 203
# Week 2: Demand = 199, On-hand before demand = 894
# Week 2: Received shipment = 402, On-hand after = 1097
# Week 2: Placing new order = 199
# Week 3: Demand = 202, On-hand before demand = 1097
# Week 3: Received shipment = 301, On-hand after = 1196
# Week 3: Placing new order = 202
# Week 4: Demand = 199, On-hand before demand = 1196
# Week 4: Received shipment = 203, On-hand after = 1200
# Week 4: Placing new order = 199
# Week 5: Demand = 199, On-hand before demand = 1200
# Week 5: Received shipment = 199, On-hand after = 1200
# Week 5: Placing new order = 199
# Week 6: Demand = 201, On-hand before demand = 1200
# Week 6: Received shipment = 202, On-hand after = 1201
# Week 6: Placing new order = 201
# Week 7: Demand = 201, On-hand before demand = 1201
# Week 7: Received shipment = 199, On-hand after = 1199
# Week 7: Placing new order = 201
# Week 8: Demand = 196, On-hand before demand = 1199
# Week 8: Received shipment = 199, On-hand after = 1202
# Week 8: Placing new order = 196
# Week 9: Demand = 202, On-hand before demand = 1202
# Week 9: Received shipment = 201, On-hand after = 1201
# Week 9: Placing new order = 202
# Week 10: Demand = 202, On-hand before demand = 1201
# Week 10: Received shipment = 201, On-hand after = 1200
# Week 10: Placing new order = 202
# Week 11: Demand = 198, On-hand before demand = 1200
# Week 11: Received shipment = 196, On-hand after = 1198
# Week 11: Placing new order = 198
# Week 12: Demand = 200, On-hand before demand = 1198
# Week 12: Received shipment = 202, On-hand after = 1200
# Week 12: Placing new order = 200
# Week 13: Demand = 200, On-hand before demand = 1200
# Week 13: Received shipment = 202, On-hand after = 1202
# Week 13: Placing new order = 200
# Week 14: Demand = 200, On-hand before demand = 1202
# Week 14: Received shipment = 198, On-hand after = 1200
# Week 14: Placing new order = 200
# Week 15: Demand = 198, On-hand before demand = 1200
# Week 15: Received shipment = 200, On-hand after = 1202
# Week 15: Placing new order = 198
# Week 16: Demand = 198, On-hand before demand = 1202
# Week 16: Received shipment = 200, On-hand after = 1204
# Week 16: Placing new order = 198
# Week 17: Demand = 199, On-hand before demand = 1204
# Week 17: Received shipment = 200, On-hand after = 1205
# Week 17: Placing new order = 199
# Week 18: Demand = 202, On-hand before demand = 1205
# Week 18: Received shipment = 198, On-hand after = 1201
# Week 18: Placing new order = 202
# Week 19: Demand = 201, On-hand before demand = 1201
# Week 19: Received shipment = 198, On-hand after = 1198
# Week 19: Placing new order = 201
# Week 20: Demand = 199, On-hand before demand = 1198
# Week 20: Received shipment = 199, On-hand after = 1198
# Week 20: Placing new order = 199
# Week 21: Demand = 201, On-hand before demand = 1198
# Week 21: Received shipment = 202, On-hand after = 1199
# Week 21: Placing new order = 201
# Week 22: Demand = 194, On-hand before demand = 1199
# Week 22: Received shipment = 201, On-hand after = 1206
# Week 22: Placing new order = 194
# Week 23: Demand = 202, On-hand before demand = 1206
# Week 23: Received shipment = 199, On-hand after = 1203
# Week 23: Placing new order = 202
# Week 24: Demand = 196, On-hand before demand = 1203
# Week 24: Received shipment = 201, On-hand after = 1208
# Week 24: Placing new order = 196
# Week 25: Demand = 199, On-hand before demand = 1208
# Week 25: Received shipment = 194, On-hand after = 1203
# Week 25: Placing new order = 199
# Week 26: Demand = 197, On-hand before demand = 1203
# Week 26: Received shipment = 202, On-hand after = 1208
# Week 26: Placing new order = 197
# Week 27: Demand = 197, On-hand before demand = 1208
# Week 27: Received shipment = 196, On-hand after = 1207
# Week 27: Placing new order = 197
# Week 28: Demand = 202, On-hand before demand = 1207
# Week 28: Received shipment = 199, On-hand after = 1204
# Week 28: Placing new order = 202
# Week 29: Demand = 199, On-hand before demand = 1204
# Week 29: Received shipment = 197, On-hand after = 1202
# Week 29: Placing new order = 199
# Week 30: Demand = 200, On-hand before demand = 1202
# Week 30: Received shipment = 197, On-hand after = 1199
# Week 30: Placing new order = 200
# Week 31: Demand = 199, On-hand before demand = 1199
# Week 31: Received shipment = 202, On-hand after = 1202
# Week 31: Placing new order = 199
# Week 32: Demand = 200, On-hand before demand = 1202
# Week 32: Received shipment = 199, On-hand after = 1201
# Week 32: Placing new order = 200
# Week 33: Demand = 200, On-hand before demand = 1201
# Week 33: Received shipment = 200, On-hand after = 1201
# Week 33: Placing new order = 200
# Week 34: Demand = 197, On-hand before demand = 1201
# Week 34: Received shipment = 199, On-hand after = 1203
# Week 34: Placing new order = 197
# Week 35: Demand = 201, On-hand before demand = 1203
# Week 35: Received shipment = 200, On-hand after = 1202
# Week 35: Placing new order = 201
# Week 36: Demand = 199, On-hand before demand = 1202
# Week 36: Received shipment = 200, On-hand after = 1203
# Week 36: Placing new order = 199
# Week 37: Demand = 196, On-hand before demand = 1203
# Week 37: Received shipment = 197, On-hand after = 1204
# Week 37: Placing new order = 196
# Week 38: Demand = 199, On-hand before demand = 1204
# Week 38: Received shipment = 201, On-hand after = 1206
# Week 38: Placing new order = 199
# Week 39: Demand = 203, On-hand before demand = 1206
# Week 39: Received shipment = 199, On-hand after = 1202
# Week 39: Placing new order = 203
# Week 40: Demand = 201, On-hand before demand = 1202
# Week 40: Received shipment = 196, On-hand after = 1197
# Week 40: Placing new order = 201
# Week 41: Demand = 199, On-hand before demand = 1197
# Week 41: Received shipment = 199, On-hand after = 1197
# Week 41: Placing new order = 199
# Week 42: Demand = 199, On-hand before demand = 1197
# Week 42: Received shipment = 203, On-hand after = 1201
# Week 42: Placing new order = 199
# Week 43: Demand = 199, On-hand before demand = 1201
# Week 43: Received shipment = 201, On-hand after = 1203
# Week 43: Placing new order = 199
# Week 44: Demand = 204, On-hand before demand = 1203
# Week 44: Received shipment = 199, On-hand after = 1198
# Week 44: Placing new order = 204
# Week 45: Demand = 200, On-hand before demand = 1198
# Week 45: Received shipment = 199, On-hand after = 1197
# Week 45: Placing new order = 200
# Week 46: Demand = 200, On-hand before demand = 1197
# Week 46: Received shipment = 199, On-hand after = 1196
# Week 46: Placing new order = 200
# Week 47: Demand = 202, On-hand before demand = 1196
# Week 47: Received shipment = 204, On-hand after = 1198
# Week 47: Placing new order = 202
# Week 48: Demand = 200, On-hand before demand = 1198
# Week 48: Received shipment = 200, On-hand after = 1198
# Week 48: Placing new order = 200
# Week 49: Demand = 199, On-hand before demand = 1198
# Week 49: Received shipment = 200, On-hand after = 1199
# Week 49: Placing new order = 199
# Week 50: Demand = 199, On-hand before demand = 1199
# Week 50: Received shipment = 202, On-hand after = 1202
# Week 50: Placing new order = 199
# Week 51: Demand = 199, On-hand before demand = 1202
# Week 51: Received shipment = 200, On-hand after = 1203
# Week 51: Placing new order = 199
# Week 52: Demand = 199, On-hand before demand = 1203
# Week 52: Received shipment = 199, On-hand after = 1203
# Week 52: Placing new order = 199
#
# Simulating policy: (200, 402, 301, 1801)
# Week 1: Demand = 201, On-hand before demand = 898
# Week 1: Received shipment = 200, On-hand after = 897
# Week 1: Placing new order = 201
# Week 2: Demand = 200, On-hand before demand = 897
# Week 2: Received shipment = 402, On-hand after = 1099
# Week 2: Placing new order = 200
# Week 3: Demand = 201, On-hand before demand = 1099
# Week 3: Received shipment = 301, On-hand after = 1199
# Week 3: Placing new order = 201
# Week 4: Demand = 199, On-hand before demand = 1199
# Week 4: Received shipment = 201, On-hand after = 1201
# Week 4: Placing new order = 199
# Week 5: Demand = 200, On-hand before demand = 1201
# Week 5: Received shipment = 200, On-hand after = 1201
# Week 5: Placing new order = 200
# Week 6: Demand = 196, On-hand before demand = 1201
# Week 6: Received shipment = 201, On-hand after = 1206
# Week 6: Placing new order = 196
# Week 7: Demand = 201, On-hand before demand = 1206
# Week 7: Received shipment = 199, On-hand after = 1204
# Week 7: Placing new order = 201
# Week 8: Demand = 200, On-hand before demand = 1204
# Week 8: Received shipment = 200, On-hand after = 1204
# Week 8: Placing new order = 200
# Week 9: Demand = 201, On-hand before demand = 1204
# Week 9: Received shipment = 196, On-hand after = 1199
# Week 9: Placing new order = 201
# Week 10: Demand = 194, On-hand before demand = 1199
# Week 10: Received shipment = 201, On-hand after = 1206
# Week 10: Placing new order = 194
# Week 11: Demand = 204, On-hand before demand = 1206
# Week 11: Received shipment = 200, On-hand after = 1202
# Week 11: Placing new order = 204
# Week 12: Demand = 199, On-hand before demand = 1202
# Week 12: Received shipment = 201, On-hand after = 1204
# Week 12: Placing new order = 199
# Week 13: Demand = 202, On-hand before demand = 1204
# Week 13: Received shipment = 194, On-hand after = 1196
# Week 13: Placing new order = 202
# Week 14: Demand = 197, On-hand before demand = 1196
# Week 14: Received shipment = 204, On-hand after = 1203
# Week 14: Placing new order = 197
# Week 15: Demand = 201, On-hand before demand = 1203
# Week 15: Received shipment = 199, On-hand after = 1201
# Week 15: Placing new order = 201
# Week 16: Demand = 197, On-hand before demand = 1201
# Week 16: Received shipment = 202, On-hand after = 1206
# Week 16: Placing new order = 197
# Week 17: Demand = 198, On-hand before demand = 1206
# Week 17: Received shipment = 197, On-hand after = 1205
# Week 17: Placing new order = 198
# Week 18: Demand = 203, On-hand before demand = 1205
# Week 18: Received shipment = 201, On-hand after = 1203
# Week 18: Placing new order = 203
# Week 19: Demand = 199, On-hand before demand = 1203
# Week 19: Received shipment = 197, On-hand after = 1201
# Week 19: Placing new order = 199
# Week 20: Demand = 200, On-hand before demand = 1201
# Week 20: Received shipment = 198, On-hand after = 1199
# Week 20: Placing new order = 200
# Week 21: Demand = 201, On-hand before demand = 1199
# Week 21: Received shipment = 203, On-hand after = 1201
# Week 21: Placing new order = 201
# Week 22: Demand = 200, On-hand before demand = 1201
# Week 22: Received shipment = 199, On-hand after = 1200
# Week 22: Placing new order = 200
# Week 23: Demand = 200, On-hand before demand = 1200
# Week 23: Received shipment = 200, On-hand after = 1200
# Week 23: Placing new order = 200
# Week 24: Demand = 200, On-hand before demand = 1200
# Week 24: Received shipment = 201, On-hand after = 1201
# Week 24: Placing new order = 200
# Week 25: Demand = 204, On-hand before demand = 1201
# Week 25: Received shipment = 200, On-hand after = 1197
# Week 25: Placing new order = 204
# Week 26: Demand = 199, On-hand before demand = 1197
# Week 26: Received shipment = 200, On-hand after = 1198
# Week 26: Placing new order = 199
# Week 27: Demand = 200, On-hand before demand = 1198
# Week 27: Received shipment = 200, On-hand after = 1198
# Week 27: Placing new order = 200
# Week 28: Demand = 202, On-hand before demand = 1198
# Week 28: Received shipment = 204, On-hand after = 1200
# Week 28: Placing new order = 202
# Week 29: Demand = 202, On-hand before demand = 1200
# Week 29: Received shipment = 199, On-hand after = 1197
# Week 29: Placing new order = 202
# Week 30: Demand = 202, On-hand before demand = 1197
# Week 30: Received shipment = 200, On-hand after = 1195
# Week 30: Placing new order = 202
# Week 31: Demand = 201, On-hand before demand = 1195
# Week 31: Received shipment = 202, On-hand after = 1196
# Week 31: Placing new order = 201
# Week 32: Demand = 197, On-hand before demand = 1196
# Week 32: Received shipment = 202, On-hand after = 1201
# Week 32: Placing new order = 197
# Week 33: Demand = 203, On-hand before demand = 1201
# Week 33: Received shipment = 202, On-hand after = 1200
# Week 33: Placing new order = 203
# Week 34: Demand = 197, On-hand before demand = 1200
# Week 34: Received shipment = 201, On-hand after = 1204
# Week 34: Placing new order = 197
# Week 35: Demand = 200, On-hand before demand = 1204
# Week 35: Received shipment = 197, On-hand after = 1201
# Week 35: Placing new order = 200
# Week 36: Demand = 198, On-hand before demand = 1201
# Week 36: Received shipment = 203, On-hand after = 1206
# Week 36: Placing new order = 198
# Week 37: Demand = 199, On-hand before demand = 1206
# Week 37: Received shipment = 197, On-hand after = 1204
# Week 37: Placing new order = 199
# Week 38: Demand = 200, On-hand before demand = 1204
# Week 38: Received shipment = 200, On-hand after = 1204
# Week 38: Placing new order = 200
# Week 39: Demand = 200, On-hand before demand = 1204
# Week 39: Received shipment = 198, On-hand after = 1202
# Week 39: Placing new order = 200
# Week 40: Demand = 200, On-hand before demand = 1202
# Week 40: Received shipment = 199, On-hand after = 1201
# Week 40: Placing new order = 200
# Week 41: Demand = 203, On-hand before demand = 1201
# Week 41: Received shipment = 200, On-hand after = 1198
# Week 41: Placing new order = 203
# Week 42: Demand = 200, On-hand before demand = 1198
# Week 42: Received shipment = 200, On-hand after = 1198
# Week 42: Placing new order = 200
# Week 43: Demand = 199, On-hand before demand = 1198
# Week 43: Received shipment = 200, On-hand after = 1199
# Week 43: Placing new order = 199
# Week 44: Demand = 201, On-hand before demand = 1199
# Week 44: Received shipment = 203, On-hand after = 1201
# Week 44: Placing new order = 201
# Week 45: Demand = 202, On-hand before demand = 1201
# Week 45: Received shipment = 200, On-hand after = 1199
# Week 45: Placing new order = 202
# Week 46: Demand = 197, On-hand before demand = 1199
# Week 46: Received shipment = 199, On-hand after = 1201
# Week 46: Placing new order = 197
# Week 47: Demand = 201, On-hand before demand = 1201
# Week 47: Received shipment = 201, On-hand after = 1201
# Week 47: Placing new order = 201
# Week 48: Demand = 201, On-hand before demand = 1201
# Week 48: Received shipment = 202, On-hand after = 1202
# Week 48: Placing new order = 201
# Week 49: Demand = 199, On-hand before demand = 1202
# Week 49: Received shipment = 197, On-hand after = 1200
# Week 49: Placing new order = 199
# Week 50: Demand = 202, On-hand before demand = 1200
# Week 50: Received shipment = 201, On-hand after = 1199
# Week 50: Placing new order = 202
# Week 51: Demand = 199, On-hand before demand = 1199
# Week 51: Received shipment = 201, On-hand after = 1201
# Week 51: Placing new order = 199
# Week 52: Demand = 200, On-hand before demand = 1201
# Week 52: Received shipment = 199, On-hand after = 1200
# Week 52: Placing new order = 200
#
# Simulating policy: (201, 402, 301, 1801)
# Week 1: Demand = 199, On-hand before demand = 897
# Week 1: Received shipment = 201, On-hand after = 899
# Week 1: Placing new order = 199
# Week 2: Demand = 200, On-hand before demand = 899
# Week 2: Received shipment = 402, On-hand after = 1101
# Week 2: Placing new order = 200
# Week 3: Demand = 197, On-hand before demand = 1101
# Week 3: Received shipment = 301, On-hand after = 1205
# Week 3: Placing new order = 197
# Week 4: Demand = 197, On-hand before demand = 1205
# Week 4: Received shipment = 199, On-hand after = 1207
# Week 4: Placing new order = 197
# Week 5: Demand = 203, On-hand before demand = 1207
# Week 5: Received shipment = 200, On-hand after = 1204
# Week 5: Placing new order = 203
# Week 6: Demand = 198, On-hand before demand = 1204
# Week 6: Received shipment = 197, On-hand after = 1203
# Week 6: Placing new order = 198
# Week 7: Demand = 198, On-hand before demand = 1203
# Week 7: Received shipment = 197, On-hand after = 1202
# Week 7: Placing new order = 198
# Week 8: Demand = 195, On-hand before demand = 1202
# Week 8: Received shipment = 203, On-hand after = 1210
# Week 8: Placing new order = 195
# Week 9: Demand = 198, On-hand before demand = 1210
# Week 9: Received shipment = 198, On-hand after = 1210
# Week 9: Placing new order = 198
# Week 10: Demand = 197, On-hand before demand = 1210
# Week 10: Received shipment = 198, On-hand after = 1211
# Week 10: Placing new order = 197
# Week 11: Demand = 203, On-hand before demand = 1211
# Week 11: Received shipment = 195, On-hand after = 1203
# Week 11: Placing new order = 203
# Week 12: Demand = 202, On-hand before demand = 1203
# Week 12: Received shipment = 198, On-hand after = 1199
# Week 12: Placing new order = 202
# Week 13: Demand = 198, On-hand before demand = 1199
# Week 13: Received shipment = 197, On-hand after = 1198
# Week 13: Placing new order = 198
# Week 14: Demand = 204, On-hand before demand = 1198
# Week 14: Received shipment = 203, On-hand after = 1197
# Week 14: Placing new order = 204
# Week 15: Demand = 201, On-hand before demand = 1197
# Week 15: Received shipment = 202, On-hand after = 1198
# Week 15: Placing new order = 201
# Week 16: Demand = 199, On-hand before demand = 1198
# Week 16: Received shipment = 198, On-hand after = 1197
# Week 16: Placing new order = 199
# Week 17: Demand = 195, On-hand before demand = 1197
# Week 17: Received shipment = 204, On-hand after = 1206
# Week 17: Placing new order = 195
# Week 18: Demand = 204, On-hand before demand = 1206
# Week 18: Received shipment = 201, On-hand after = 1203
# Week 18: Placing new order = 204
# Week 19: Demand = 197, On-hand before demand = 1203
# Week 19: Received shipment = 199, On-hand after = 1205
# Week 19: Placing new order = 197
# Week 20: Demand = 196, On-hand before demand = 1205
# Week 20: Received shipment = 195, On-hand after = 1204
# Week 20: Placing new order = 196
# Week 21: Demand = 202, On-hand before demand = 1204
# Week 21: Received shipment = 204, On-hand after = 1206
# Week 21: Placing new order = 202
# Week 22: Demand = 204, On-hand before demand = 1206
# Week 22: Received shipment = 197, On-hand after = 1199
# Week 22: Placing new order = 204
# Week 23: Demand = 202, On-hand before demand = 1199
# Week 23: Received shipment = 196, On-hand after = 1193
# Week 23: Placing new order = 202
# Week 24: Demand = 201, On-hand before demand = 1193
# Week 24: Received shipment = 202, On-hand after = 1194
# Week 24: Placing new order = 201
# Week 25: Demand = 201, On-hand before demand = 1194
# Week 25: Received shipment = 204, On-hand after = 1197
# Week 25: Placing new order = 201
# Week 26: Demand = 201, On-hand before demand = 1197
# Week 26: Received shipment = 202, On-hand after = 1198
# Week 26: Placing new order = 201
# Week 27: Demand = 201, On-hand before demand = 1198
# Week 27: Received shipment = 201, On-hand after = 1198
# Week 27: Placing new order = 201
# Week 28: Demand = 200, On-hand before demand = 1198
# Week 28: Received shipment = 201, On-hand after = 1199
# Week 28: Placing new order = 200
# Week 29: Demand = 200, On-hand before demand = 1199
# Week 29: Received shipment = 201, On-hand after = 1200
# Week 29: Placing new order = 200
# Week 30: Demand = 199, On-hand before demand = 1200
# Week 30: Received shipment = 201, On-hand after = 1202
# Week 30: Placing new order = 199
# Week 31: Demand = 198, On-hand before demand = 1202
# Week 31: Received shipment = 200, On-hand after = 1204
# Week 31: Placing new order = 198
# Week 32: Demand = 199, On-hand before demand = 1204
# Week 32: Received shipment = 200, On-hand after = 1205
# Week 32: Placing new order = 199
# Week 33: Demand = 196, On-hand before demand = 1205
# Week 33: Received shipment = 199, On-hand after = 1208
# Week 33: Placing new order = 196
# Week 34: Demand = 199, On-hand before demand = 1208
# Week 34: Received shipment = 198, On-hand after = 1207
# Week 34: Placing new order = 199
# Week 35: Demand = 198, On-hand before demand = 1207
# Week 35: Received shipment = 199, On-hand after = 1208
# Week 35: Placing new order = 198
# Week 36: Demand = 197, On-hand before demand = 1208
# Week 36: Received shipment = 196, On-hand after = 1207
# Week 36: Placing new order = 197
# Week 37: Demand = 200, On-hand before demand = 1207
# Week 37: Received shipment = 199, On-hand after = 1206
# Week 37: Placing new order = 200
# Week 38: Demand = 202, On-hand before demand = 1206
# Week 38: Received shipment = 198, On-hand after = 1202
# Week 38: Placing new order = 202
# Week 39: Demand = 201, On-hand before demand = 1202
# Week 39: Received shipment = 197, On-hand after = 1198
# Week 39: Placing new order = 201
# Week 40: Demand = 196, On-hand before demand = 1198
# Week 40: Received shipment = 200, On-hand after = 1202
# Week 40: Placing new order = 196
# Week 41: Demand = 198, On-hand before demand = 1202
# Week 41: Received shipment = 202, On-hand after = 1206
# Week 41: Placing new order = 198
# Week 42: Demand = 201, On-hand before demand = 1206
# Week 42: Received shipment = 201, On-hand after = 1206
# Week 42: Placing new order = 201
# Week 43: Demand = 198, On-hand before demand = 1206
# Week 43: Received shipment = 196, On-hand after = 1204
# Week 43: Placing new order = 198
# Week 44: Demand = 199, On-hand before demand = 1204
# Week 44: Received shipment = 198, On-hand after = 1203
# Week 44: Placing new order = 199
# Week 45: Demand = 201, On-hand before demand = 1203
# Week 45: Received shipment = 201, On-hand after = 1203
# Week 45: Placing new order = 201
# Week 46: Demand = 198, On-hand before demand = 1203
# Week 46: Received shipment = 198, On-hand after = 1203
# Week 46: Placing new order = 198
# Week 47: Demand = 200, On-hand before demand = 1203
# Week 47: Received shipment = 199, On-hand after = 1202
# Week 47: Placing new order = 200
# Week 48: Demand = 197, On-hand before demand = 1202
# Week 48: Received shipment = 201, On-hand after = 1206
# Week 48: Placing new order = 197
# Week 49: Demand = 198, On-hand before demand = 1206
# Week 49: Received shipment = 198, On-hand after = 1206
# Week 49: Placing new order = 198
# Week 50: Demand = 200, On-hand before demand = 1206
# Week 50: Received shipment = 200, On-hand after = 1206
# Week 50: Placing new order = 200
# Week 51: Demand = 196, On-hand before demand = 1206
# Week 51: Received shipment = 197, On-hand after = 1207
# Week 51: Placing new order = 196
# Week 52: Demand = 200, On-hand before demand = 1207
# Week 52: Received shipment = 198, On-hand after = 1205
# Week 52: Placing new order = 200
#
# Simulating policy: (201, 402, 301, 1803)
# Week 1: Demand = 199, On-hand before demand = 899
# Week 1: Received shipment = 201, On-hand after = 901
# Week 1: Placing new order = 199
# Week 2: Demand = 201, On-hand before demand = 901
# Week 2: Received shipment = 402, On-hand after = 1102
# Week 2: Placing new order = 201
# Week 3: Demand = 200, On-hand before demand = 1102
# Week 3: Received shipment = 301, On-hand after = 1203
# Week 3: Placing new order = 200
# Week 4: Demand = 202, On-hand before demand = 1203
# Week 4: Received shipment = 199, On-hand after = 1200
# Week 4: Placing new order = 202
# Week 5: Demand = 200, On-hand before demand = 1200
# Week 5: Received shipment = 201, On-hand after = 1201
# Week 5: Placing new order = 200
# Week 6: Demand = 199, On-hand before demand = 1201
# Week 6: Received shipment = 200, On-hand after = 1202
# Week 6: Placing new order = 199
# Week 7: Demand = 200, On-hand before demand = 1202
# Week 7: Received shipment = 202, On-hand after = 1204
# Week 7: Placing new order = 200
# Week 8: Demand = 201, On-hand before demand = 1204
# Week 8: Received shipment = 200, On-hand after = 1203
# Week 8: Placing new order = 201
# Week 9: Demand = 200, On-hand before demand = 1203
# Week 9: Received shipment = 199, On-hand after = 1202
# Week 9: Placing new order = 200
# Week 10: Demand = 200, On-hand before demand = 1202
# Week 10: Received shipment = 200, On-hand after = 1202
# Week 10: Placing new order = 200
# Week 11: Demand = 198, On-hand before demand = 1202
# Week 11: Received shipment = 201, On-hand after = 1205
# Week 11: Placing new order = 198
# Week 12: Demand = 198, On-hand before demand = 1205
# Week 12: Received shipment = 200, On-hand after = 1207
# Week 12: Placing new order = 198
# Week 13: Demand = 197, On-hand before demand = 1207
# Week 13: Received shipment = 200, On-hand after = 1210
# Week 13: Placing new order = 197
# Week 14: Demand = 203, On-hand before demand = 1210
# Week 14: Received shipment = 198, On-hand after = 1205
# Week 14: Placing new order = 203
# Week 15: Demand = 197, On-hand before demand = 1205
# Week 15: Received shipment = 198, On-hand after = 1206
# Week 15: Placing new order = 197
# Week 16: Demand = 198, On-hand before demand = 1206
# Week 16: Received shipment = 197, On-hand after = 1205
# Week 16: Placing new order = 198
# Week 17: Demand = 198, On-hand before demand = 1205
# Week 17: Received shipment = 203, On-hand after = 1210
# Week 17: Placing new order = 198
# Week 18: Demand = 201, On-hand before demand = 1210
# Week 18: Received shipment = 197, On-hand after = 1206
# Week 18: Placing new order = 201
# Week 19: Demand = 199, On-hand before demand = 1206
# Week 19: Received shipment = 198, On-hand after = 1205
# Week 19: Placing new order = 199
# Week 20: Demand = 202, On-hand before demand = 1205
# Week 20: Received shipment = 198, On-hand after = 1201
# Week 20: Placing new order = 202
# Week 21: Demand = 198, On-hand before demand = 1201
# Week 21: Received shipment = 201, On-hand after = 1204
# Week 21: Placing new order = 198
# Week 22: Demand = 200, On-hand before demand = 1204
# Week 22: Received shipment = 199, On-hand after = 1203
# Week 22: Placing new order = 200
# Week 23: Demand = 198, On-hand before demand = 1203
# Week 23: Received shipment = 202, On-hand after = 1207
# Week 23: Placing new order = 198
# Week 24: Demand = 204, On-hand before demand = 1207
# Week 24: Received shipment = 198, On-hand after = 1201
# Week 24: Placing new order = 204
# Week 25: Demand = 197, On-hand before demand = 1201
# Week 25: Received shipment = 200, On-hand after = 1204
# Week 25: Placing new order = 197
# Week 26: Demand = 200, On-hand before demand = 1204
# Week 26: Received shipment = 198, On-hand after = 1202
# Week 26: Placing new order = 200
# Week 27: Demand = 201, On-hand before demand = 1202
# Week 27: Received shipment = 204, On-hand after = 1205
# Week 27: Placing new order = 201
# Week 28: Demand = 200, On-hand before demand = 1205
# Week 28: Received shipment = 197, On-hand after = 1202
# Week 28: Placing new order = 200
# Week 29: Demand = 199, On-hand before demand = 1202
# Week 29: Received shipment = 200, On-hand after = 1203
# Week 29: Placing new order = 199
# Week 30: Demand = 199, On-hand before demand = 1203
# Week 30: Received shipment = 201, On-hand after = 1205
# Week 30: Placing new order = 199
# Week 31: Demand = 200, On-hand before demand = 1205
# Week 31: Received shipment = 200, On-hand after = 1205
# Week 31: Placing new order = 200
# Week 32: Demand = 199, On-hand before demand = 1205
# Week 32: Received shipment = 199, On-hand after = 1205
# Week 32: Placing new order = 199
# Week 33: Demand = 201, On-hand before demand = 1205
# Week 33: Received shipment = 199, On-hand after = 1203
# Week 33: Placing new order = 201
# Week 34: Demand = 204, On-hand before demand = 1203
# Week 34: Received shipment = 200, On-hand after = 1199
# Week 34: Placing new order = 204
# Week 35: Demand = 198, On-hand before demand = 1199
# Week 35: Received shipment = 199, On-hand after = 1200
# Week 35: Placing new order = 198
# Week 36: Demand = 197, On-hand before demand = 1200
# Week 36: Received shipment = 201, On-hand after = 1204
# Week 36: Placing new order = 197
# Week 37: Demand = 199, On-hand before demand = 1204
# Week 37: Received shipment = 204, On-hand after = 1209
# Week 37: Placing new order = 199
# Week 38: Demand = 205, On-hand before demand = 1209
# Week 38: Received shipment = 198, On-hand after = 1202
# Week 38: Placing new order = 205
# Week 39: Demand = 198, On-hand before demand = 1202
# Week 39: Received shipment = 197, On-hand after = 1201
# Week 39: Placing new order = 198
# Week 40: Demand = 203, On-hand before demand = 1201
# Week 40: Received shipment = 199, On-hand after = 1197
# Week 40: Placing new order = 203
# Week 41: Demand = 203, On-hand before demand = 1197
# Week 41: Received shipment = 205, On-hand after = 1199
# Week 41: Placing new order = 203
# Week 42: Demand = 198, On-hand before demand = 1199
# Week 42: Received shipment = 198, On-hand after = 1199
# Week 42: Placing new order = 198
# Week 43: Demand = 201, On-hand before demand = 1199
# Week 43: Received shipment = 203, On-hand after = 1201
# Week 43: Placing new order = 201
# Week 44: Demand = 203, On-hand before demand = 1201
# Week 44: Received shipment = 203, On-hand after = 1201
# Week 44: Placing new order = 203
# Week 45: Demand = 199, On-hand before demand = 1201
# Week 45: Received shipment = 198, On-hand after = 1200
# Week 45: Placing new order = 199
# Week 46: Demand = 199, On-hand before demand = 1200
# Week 46: Received shipment = 201, On-hand after = 1202
# Week 46: Placing new order = 199
# Week 47: Demand = 198, On-hand before demand = 1202
# Week 47: Received shipment = 203, On-hand after = 1207
# Week 47: Placing new order = 198
# Week 48: Demand = 197, On-hand before demand = 1207
# Week 48: Received shipment = 199, On-hand after = 1209
# Week 48: Placing new order = 197
# Week 49: Demand = 198, On-hand before demand = 1209
# Week 49: Received shipment = 199, On-hand after = 1210
# Week 49: Placing new order = 198
# Week 50: Demand = 197, On-hand before demand = 1210
# Week 50: Received shipment = 198, On-hand after = 1211
# Week 50: Placing new order = 197
# Week 51: Demand = 200, On-hand before demand = 1211
# Week 51: Received shipment = 197, On-hand after = 1208
# Week 51: Placing new order = 200
# Week 52: Demand = 198, On-hand before demand = 1208
# Week 52: Received shipment = 198, On-hand after = 1208
# Week 52: Placing new order = 198

# %% [markdown]
# In the above cell the function simulates inventory performance based on given policy and weeks.
#
# Args:
#     policy (tuple): A tuple containing (transit_1, transit_2, transit_3, order_up_to).
#     weeks (int): Number of weeks to simulate.
#
# Returns:
#     tuple: Average inventory level and average fill rate.

# %% [markdown]
# # Selecting Best Policy

# %%
best_policy = min(results, key=lambda x: (abs(x[1] - 1800), -x[2]))

# %%
print ("Best Policy : ", best_policy)
# Out:
# Best Policy :  ((200, 400, 300, 1800), 1800.0, 1.0)

# %% [markdown]
# # Simulation Results

# %%
print("\nSimulation Results:")
for policy, avg_inventory, avg_fill_rate in results:
    print(f"Policy {policy}: Avg Inventory = {avg_inventory:.2f}, Fill Rate = {avg_fill_rate:.2%}")

print("\nRecommended Policy:", best_policy[0])
# Out:
# Simulation Results:
# Policy (200, 400, 300, 1800): Avg Inventory = 1800.00, Fill Rate = 100.00%
# Policy (200, 400, 300, 1804): Avg Inventory = 1804.00, Fill Rate = 100.00%
# Policy (200, 400, 300, 1805): Avg Inventory = 1805.00, Fill Rate = 100.00%
# Policy (200, 400, 300, 1807): Avg Inventory = 1807.00, Fill Rate = 100.00%
# Policy (200, 402, 301, 1800): Avg Inventory = 1800.00, Fill Rate = 100.00%
# Policy (200, 402, 301, 1801): Avg Inventory = 1801.00, Fill Rate = 100.00%
# Policy (201, 402, 301, 1801): Avg Inventory = 1801.00, Fill Rate = 100.00%
# Policy (201, 402, 301, 1803): Avg Inventory = 1803.00, Fill Rate = 100.00%
#
# Recommended Policy: (200, 400, 300, 1800)

# %%
# Plot inventory levels over time
plt.figure(figsize=(12, 6))
for policy, inventory_levels in policy_inventory_levels.items():
    plt.plot(inventory_levels, label=f"Policy {policy}", linewidth=1.5)

plt.axhline(y=1800, color='r', linestyle='--', label='Target Inventory (1800)')
plt.xlabel("Weeks")
plt.ylabel("Inventory Level")
plt.title("Inventory Levels Over Time for Different Policies")
plt.grid(True, linestyle='--', linewidth=0.5)
plt.legend(loc='upper right', fontsize='small', bbox_to_anchor=(1.3, 1))
plt.show()

# %% [markdown]
# ### Interpretation of Results & Business Logic
#
# - **Best Inventory Policy:** The optimal policy is **(200, 400, 300, 1800)**, as it maintains an **average inventory of 1800** while achieving a **100% fill rate**.
# - **Efficiency & Cost Management:** Policies exceeding 1800 (e.g., 1804, 1805, 1807) do not improve fill rates, meaning excess stock leads to **higher holding costs** with no added benefit.
# - **Demand Fulfillment:** All tested policies resulted in a **100% fill rate**, indicating that even the lowest recommended inventory level can meet demand consistently.
# - **Recommendation:** Stick to **(200, 400, 300, 1800)** for **cost-efficient inventory management**, ensuring stock availability while minimizing excess.
